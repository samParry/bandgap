# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sheet = pd.read_excel('data.xlsx')
corrmat = sheet.corr().round(2)
f, ax = plt.subplots(figsize =(7, 6))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1, annot=True)

# %%
c1 = sheet['C_1']
c2 = sheet['C_2']
h = sheet['h']
r = sheet['r_0']
phi = sheet['Phi']
rb = sheet['RB']

corrmat['RB']
# Out:
# C_1    0.46
# C_2   -0.38
# h     -0.48
# r_0    0.20
# Phi    0.17
# RB     1.00
# Name: RB, dtype: float64

# %%
round(rb.corr(c1-c2), 2)
# Out:
# 0.59

# %% [markdown]
# **Plan**
#
# **Results**
#
# c1-c2 -> 0.59 (best)
#
# abs sucks
#
# **Operators**
#
# C_1 and C_2 can be negative -> use abs()
#
# Comparative: +, -, *, ^2
#
#
# **Goal**
#
# A bar graph showing different features on the x (e.g. c1+c2, abs(rho)) and their correlation to RB on the y
